# %% [markdown]
# ![RegressionExample.jpg](attachment:074db5fe-a7c6-4be2-b728-2f4d3fc9b546.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([10, 22, 34, 35, 45, 50, 63]).reshape(-1, 1)
y = np.array([23, 45, 71, 73, 93, 103, 128]).reshape(-1, 1)

# %%
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
Regressor = LinearRegression()
Regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
print(Regressor.coef_)
print(Regressor.intercept_)
# Out:
# [[2.0021322]]
# [2.49253731]

# %%
y_pred = Regressor.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
x = int(input("Enter x vlaue: "))
x = np.array(x).reshape(-1, 1)
prediction = Regressor.predict(x)
print(f"y = {round(prediction[0][0])}")
# Out:
# Enter x vlaue:  100
# y = 203
